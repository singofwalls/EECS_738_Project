# %%
# Big thanks to Eligijus Bujokas, who designed the DeepModelTS class. Link to his Towards Data Science article about it is below:
# https://towardsdatascience.com/energy-consumption-time-series-forecasting-with-python-and-lstm-deep-learning-model-7952e2f9a796 

# Data wrangling
import pandas as pd
import numpy as np

# Deep learning: 
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Plotting:
import matplotlib.pyplot as plt


class DeepModelTS():
    """
    A class to create a deep time series model
    """
    def __init__(
        self, 
        data: pd.DataFrame, 
        Y_var: str,
        lag: int,
        LSTM_layer_depth: int, 
        epochs=10, 
        batch_size=256,
        train_test_split=0
    ):

        self.data = data 
        self.Y_var = Y_var 
        self.lag = lag 
        self.LSTM_layer_depth = LSTM_layer_depth
        self.batch_size = batch_size
        self.epochs = epochs
        self.train_test_split = train_test_split

    @staticmethod
    def create_X_Y(ts: list, lag: int) -> tuple:
        """
        A method to create X and Y matrix from a time series list for the training of 
        deep learning models 
        """
        X, Y = [], []

        if len(ts) - lag <= 0:
            X.append(ts)
        else:
            for i in range(len(ts) - lag):
                Y.append(ts[i + lag])
                X.append(ts[i:(i + lag)])

        X, Y = np.array(X), np.array(Y)

        # Reshaping the X array to an LSTM input shape 
        X = np.reshape(X, (X.shape[0], X.shape[1], 1))

        return X, Y         

    def create_data_for_NN(
        self,
        use_last_n=None
        ):
        """
        A method to create data for the neural network model
        """
        # Extracting the main variable we want to model/forecast
        y = self.data[self.Y_var].tolist()

        # Subseting the time series if needed
        if use_last_n is not None:
            y = y[-use_last_n:]

        # The X matrix will hold the lags of Y 
        X, Y = self.create_X_Y(y, self.lag)

        # Creating training and test sets 
        X_train = X
        X_test = []

        Y_train = Y
        Y_test = []

        if self.train_test_split > 0:
            index = round(len(X) * self.train_test_split)
            X_train = X[:(len(X) - index)]
            X_test = X[-index:]     
            
            Y_train = Y[:(len(X) - index)]
            Y_test = Y[-index:]

        return X_train, X_test, Y_train, Y_test

    def LSTModel(self):
        """
        A method to fit the LSTM model 
        """
        # Getting the data 
        X_train, X_test, Y_train, Y_test = self.create_data_for_NN()

        # Defining the model
        model = Sequential()
        model.add(LSTM(self.LSTM_layer_depth, activation='relu', input_shape=(self.lag, 1)))
        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mse')

        # Defining the model parameter dict 
        keras_dict = {
            'x': X_train,
            'y': Y_train,
            'batch_size': self.batch_size,
            'epochs': self.epochs,
            'shuffle': False
        }

        if self.train_test_split > 0:
            keras_dict.update({
                'validation_data': (X_test, Y_test)
            })

        # Fitting the model 
        model.fit(
            **keras_dict
        )

        # Saving the model to the class 
        self.model = model

        return model

    def predict(self) -> list:
        """
        A method to predict using the test data used in creating the class
        """
        yhat = []

        if(self.train_test_split > 0):
        
            # Getting the last n time series 
            _, X_test, _, _ = self.create_data_for_NN()        

            # Making the prediction list 
            yhat = [y[0] for y in self.model.predict(X_test)]

        return yhat

    def predict_n_ahead(self, n_ahead: int):
        """
        A method to predict n time steps ahead
        """    
        X, _, _, _ = self.create_data_for_NN(use_last_n=self.lag)
        print(len(X))
        # Making the prediction list 
        yhat = []

        for _ in range(n_ahead):
            # Making the prediction
            fc = self.model.predict(X)
            yhat.append(fc)

            # Creating a new input matrix for forecasting
            X = np.append(X, fc)

            # Ommiting the first variable
            X = np.delete(X, 0)

            # Reshaping for the next iteration
            X = np.reshape(X, (1, len(X), 1))

        return yhat

# getting the data
df = pd.read_csv('values_normalized.csv')
df = df.dropna()

#initializing the model
deep_learner = DeepModelTS(
data = df,
Y_var = 'tas',
lag = 500,
LSTM_layer_depth = 50,
epochs = 10,
batch_size = 256,
train_test_split = 0.15
)

#training (or fitting) the model
model = deep_learner.LSTModel()

#making predictions for the test dataset
yhat = deep_learner.predict()
# Out:
# Epoch 1/10
# 68/68 [==============================] - 35s 493ms/step - loss: 0.0890 - val_loss: 0.0043
# Epoch 2/10
# 68/68 [==============================] - 37s 547ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 3/10
# 68/68 [==============================] - 40s 586ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 4/10
# 68/68 [==============================] - 40s 582ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 5/10
# 68/68 [==============================] - 39s 574ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 6/10
# 68/68 [==============================] - 40s 584ms/step - loss: 0.0011 - val_loss: 9.8468e-04
# Epoch 7/10
# 68/68 [==============================] - 40s 589ms/step - loss: nan - val_loss: nan
# Epoch 8/10
# 68/68 [==============================] - 40s 591ms/step - loss: nan - val_loss: nan
# Epoch 9/10
# 68/68 [==============================] - 40s 589ms/step - loss: nan - val_loss: nan
# Epoch 10/10
# 68/68 [==============================] - 41s 596ms/step - loss: nan - val_loss: nan

# %%
#creating graph comparing predictions and actual values for the test dataset
fc = df.tail(len(yhat)).copy()
fc.reset_index(inplace=True)
fc['forecast'] = yhat
plt.figure(figsize=(12, 8))
plt.plot(fc['day'], fc['tas'], label='actual')
plt.plot(fc['day'], fc['forecast'], label='predicted')
plt.xlabel("day")
plt.ylabel("tas")
plt.title("Test dataset performance")
plt.legend()
plt.show()

# %%
if SAVE_MODEL := False:
    model.save("lstm")
# Out:
# INFO:tensorflow:Assets written to: lstm\assets
# INFO:tensorflow:Assets written to: lstm\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000001BE4928CD30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
if LOAD_FROM_FILE := True:
    # Load model from file
    import keras.models
    model = keras.models.load_model("lstm 1000")
    deep_learner = DeepModelTS(
        data = df,
        Y_var = 'tas',
        lag = 1000,
        LSTM_layer_depth = 50,
        epochs = 10,
        batch_size = 256,
        train_test_split = 0.15
    )
    deep_learner.model = model
    yhat = deep_learner.predict()
# Out:
# [[nan]
#  [nan]
#  [nan]
#  ...
#  [nan]
#  [nan]
#  [nan]]

# %%
#predicting the tas n days ahead
n_ahead = 200
yhat_future = deep_learner.predict_n_ahead(n_ahead)
yhat_future = [y[0][0] for y in yhat_future]
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\lstm_model_1_input_feature.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000005?line=0'>1</a> #predicting the tas n days ahead
#       <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000005?line=1'>2</a> n_ahead = 200
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000005?line=2'>3</a> yhat_future = deep_learner.predict_n_ahead(n_ahead)
#       <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000005?line=3'>4</a> yhat_future = [y[0][0] for y in yhat_future]
#
# c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\lstm_model_1_input_feature.ipynb Cell 1' in DeepModelTS.predict_n_ahead(self, n_ahead)
#     <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000000?line=154'>155</a> yhat = []
#     <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000000?line=156'>157</a> for _ in range(n_ahead):
#     <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000000?line=157'>158</a>     # Making the prediction
# --> <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000000?line=158'>159</a>     fc = self.model.predict(X)
#     <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000000?line=159'>160</a>     yhat.append(fc)
#     <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model_1_input_feature.ipynb#ch0000000?line=161'>162</a>     # Creating a new input matrix for forecasting
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\keras\engine\training.py:1951, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1943'>1944</a>   except ValueError:
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1944'>1945</a>     warnings.warn(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1945'>1946</a>         'Using Model.predict with MultiWorkerMirroredStrategy or '
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1946'>1947</a>         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1947'>1948</a>         'result. Consider setting it to AutoShardPolicy.DATA.',
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1948'>1949</a>         stacklevel=2)
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1950'>1951</a> data_handler = data_adapter.get_data_handler(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1951'>1952</a>     x=x,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1952'>1953</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1953'>1954</a>     steps_per_epoch=steps,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1954'>1955</a>     initial_epoch=0,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1955'>1956</a>     epochs=1,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1956'>1957</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1957'>1958</a>     workers=workers,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1958'>1959</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1959'>1960</a>     model=self,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1960'>1961</a>     steps_per_execution=self._steps_per_execution)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1962'>1963</a> # Container that configures and calls `tf.keras.Callback`s.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/training.py?line=1963'>1964</a> if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\keras\engine\data_adapter.py:1399, in get_data_handler(*args, **kwargs)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1396'>1397</a> if getattr(kwargs["model"], "_cluster_coordinator", None):
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1397'>1398</a>   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1398'>1399</a> return DataHandler(*args, **kwargs)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1145'>1146</a>   self._steps_per_execution = steps_per_execution
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1147'>1148</a> adapter_cls = select_data_adapter(x, y)
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1148'>1149</a> self._adapter = adapter_cls(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1149'>1150</a>     x,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1150'>1151</a>     y,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1151'>1152</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1152'>1153</a>     steps=steps_per_epoch,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1153'>1154</a>     epochs=epochs - initial_epoch,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1154'>1155</a>     sample_weights=sample_weight,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1155'>1156</a>     shuffle=shuffle,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1156'>1157</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1157'>1158</a>     workers=workers,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1158'>1159</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1159'>1160</a>     distribution_strategy=tf.distribute.get_strategy(),
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1160'>1161</a>     model=model)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1162'>1163</a> strategy = tf.distribute.get_strategy()
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=1164'>1165</a> self._current_step = 0
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\keras\engine\data_adapter.py:292, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=285'>286</a>   return indices
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=287'>288</a> # We prefetch a single element. Computing large permutations can take quite
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=288'>289</a> # a while so we don't want to wait for prefetching over an epoch boundary to
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=289'>290</a> # trigger the next permutation. On the other hand, too many simultaneous
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=290'>291</a> # shuffles can contend on a hardware level and degrade all performance.
# --> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=291'>292</a> indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=293'>294</a> def slice_batch_indices(indices):
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=294'>295</a>   """Convert a Tensor of indices into a dataset of batched indices.
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=295'>296</a>
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=296'>297</a>   This step can be accomplished in several ways. The most natural is to
#    (...)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=307'>308</a>     A Dataset of batched indices.
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/keras/engine/data_adapter.py?line=308'>309</a>   """
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2016, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2012'>2013</a>   if deterministic is not None and not DEBUG_MODE:
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2013'>2014</a>     warnings.warn("The `deterministic` argument has no effect unless the "
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2014'>2015</a>                   "`num_parallel_calls` argument is specified.")
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2015'>2016</a>   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2016'>2017</a> else:
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2017'>2018</a>   return ParallelMapDataset(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2018'>2019</a>       self,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2019'>2020</a>       map_func,
#    (...)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2022'>2023</a>       preserve_cardinality=True,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2023'>2024</a>       name=name)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5191, in MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5188'>5189</a> self._use_inter_op_parallelism = use_inter_op_parallelism
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5189'>5190</a> self._preserve_cardinality = preserve_cardinality
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5190'>5191</a> self._map_func = structured_function.StructuredFunctionWrapper(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5191'>5192</a>     map_func,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5192'>5193</a>     self._transformation_name(),
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5193'>5194</a>     dataset=input_dataset,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5194'>5195</a>     use_legacy_function=use_legacy_function)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5195'>5196</a> self._metadata = dataset_metadata_pb2.Metadata()
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5196'>5197</a> if name:
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\data\ops\structured_function.py:271, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=263'>264</a>       warnings.warn(
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=264'>265</a>           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=265'>266</a>           "option is set, this option does not apply to tf.data functions. "
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=266'>267</a>           "To force eager execution of tf.data functions, please use "
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=267'>268</a>           "`tf.data.experimental.enable_debug_mode()`.")
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=268'>269</a>     fn_factory = trace_tf_function(defun_kwargs)
# --> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=270'>271</a> self._function = fn_factory()
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=271'>272</a> # There is no graph to add in eager mode.
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/data/ops/structured_function.py?line=272'>273</a> add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\eager\function.py:3070, in Function.get_concrete_function(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3060'>3061</a> def get_concrete_function(self, *args, **kwargs):
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3061'>3062</a>   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3062'>3063</a>
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3063'>3064</a>   Args:
#    (...)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3067'>3068</a>        or `tf.Tensor` or `tf.TensorSpec`.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3068'>3069</a>   """
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3069'>3070</a>   graph_function = self._get_concrete_function_garbage_collected(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3070'>3071</a>       *args, **kwargs)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3071'>3072</a>   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3072'>3073</a>   return graph_function
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\eager\function.py:3036, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3033'>3034</a>   args, kwargs = None, None
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3034'>3035</a> with self._lock:
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3035'>3036</a>   graph_function, _ = self._maybe_define_function(args, kwargs)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3036'>3037</a>   seen_names = set()
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3037'>3038</a>   captured = object_identity.ObjectIdentitySet(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3038'>3039</a>       graph_function.graph.internal_captures)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\eager\function.py:3292, in Function._maybe_define_function(self, args, kwargs)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3287'>3288</a>   return self._define_function_with_shape_relaxation(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3288'>3289</a>       args, kwargs, flat_args, filtered_flat_args)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3290'>3291</a> self._function_cache.add_call_context(cache_key.call_context)
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3291'>3292</a> graph_function = self._create_graph_function(args, kwargs)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3292'>3293</a> self._function_cache.add(cache_key, cache_key_deletion_observer,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3293'>3294</a>                          graph_function)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3295'>3296</a> return graph_function, filtered_flat_args
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3124'>3125</a> missing_arg_names = [
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3125'>3126</a>     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3126'>3127</a> ]
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3127'>3128</a> arg_names = base_arg_names + missing_arg_names
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3128'>3129</a> graph_function = ConcreteFunction(
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3129'>3130</a>     func_graph_module.func_graph_from_py_func(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3130'>3131</a>         self._name,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3131'>3132</a>         self._python_function,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3132'>3133</a>         args,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3133'>3134</a>         kwargs,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3134'>3135</a>         self.input_signature,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3135'>3136</a>         autograph=self._autograph,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3136'>3137</a>         autograph_options=self._autograph_options,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3137'>3138</a>         arg_names=arg_names,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3138'>3139</a>         override_flat_arg_shapes=override_flat_arg_shapes,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3139'>3140</a>         capture_by_value=self._capture_by_value),
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3140'>3141</a>     self._function_attributes,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3141'>3142</a>     function_spec=self.function_spec,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3142'>3143</a>     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3143'>3144</a>     # scope. This is not the default behavior since it gets used in some
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3144'>3145</a>     # places (like Keras) where the FuncGraph lives longer than the
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3145'>3146</a>     # ConcreteFunction.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3146'>3147</a>     shared_func_graph=False)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/function.py?line=3147'>3148</a> return graph_function
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\framework\func_graph.py:1075, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1072'>1073</a>   arg_shapes = None
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1073'>1074</a>   kwarg_shapes = None
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1074'>1075</a> func_args = _get_defun_inputs_from_args(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1075'>1076</a>     args, arg_names, flat_shapes=arg_shapes)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1076'>1077</a> func_kwargs = _get_defun_inputs_from_kwargs(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1077'>1078</a>     kwargs, flat_shapes=kwarg_shapes)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1079'>1080</a> # Convert all Tensors into TensorSpecs before saving the structured inputs.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1080'>1081</a> # If storing pure concrete functions that are not called through polymorphic
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1081'>1082</a> # functions, we don't have access to FunctionSpec, so we need to call the
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1082'>1083</a> # TensorSpecs by their `arg_names` for later binding.
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\framework\func_graph.py:1313, in _get_defun_inputs_from_args(args, names, flat_shapes)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1310'>1311</a> def _get_defun_inputs_from_args(args, names, flat_shapes=None):
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1311'>1312</a>   """Maps Python function positional args to graph-construction inputs."""
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1312'>1313</a>   return _get_defun_inputs(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1313'>1314</a>       args, names, structure=args, flat_shapes=flat_shapes)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\framework\func_graph.py:1386, in _get_defun_inputs(args, names, structure, flat_shapes)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1383'>1384</a> placeholder_shape = shape if shape is not None else arg.shape
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1384'>1385</a> try:
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1385'>1386</a>   placeholder = graph_placeholder(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1386'>1387</a>       arg.dtype, placeholder_shape,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1387'>1388</a>       name=requested_name)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1388'>1389</a> except ValueError:
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1389'>1390</a>   # Sometimes parameter names are not valid op names, so fall back to
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1390'>1391</a>   # unnamed placeholders.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1391'>1392</a>   placeholder = graph_placeholder(arg.dtype, placeholder_shape)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\eager\graph_only_ops.py:34, in graph_placeholder(dtype, shape, name)
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=31'>32</a> g = ops.get_default_graph()
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=32'>33</a> attrs = {"dtype": dtype_value, "shape": shape}
# ---> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=33'>34</a> op = g._create_op_internal(  # pylint: disable=protected-access
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=34'>35</a>     "Placeholder", [], [dtype], input_types=[],
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=35'>36</a>     attrs=attrs, name=name)
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=36'>37</a> result, = op.outputs
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=37'>38</a> if op_callbacks.should_invoke_op_callbacks():
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=38'>39</a>   # TODO(b/147670703): Once the special-op creation code paths
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/eager/graph_only_ops.py?line=39'>40</a>   # are unified. Remove this `if` block.
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\framework\func_graph.py:693, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=690'>691</a>   inp = self.capture(inp)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=691'>692</a>   captured_inputs.append(inp)
# --> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=692'>693</a> return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=693'>694</a>     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/func_graph.py?line=694'>695</a>     compute_device)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\framework\ops.py:3776, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3772'>3773</a> # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3773'>3774</a> # Session.run call cannot occur between creating and mutating the op.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3774'>3775</a> with self._mutation_lock():
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3775'>3776</a>   ret = Operation(
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3776'>3777</a>       node_def,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3777'>3778</a>       self,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3778'>3779</a>       inputs=inputs,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3779'>3780</a>       output_types=dtypes,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3780'>3781</a>       control_inputs=control_inputs,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3781'>3782</a>       input_types=input_types,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3782'>3783</a>       original_op=self._default_original_op,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3783'>3784</a>       op_def=op_def)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3784'>3785</a>   self._create_op_helper(ret, compute_device=compute_device)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=3785'>3786</a> return ret
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\framework\ops.py:2171, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2168'>2169</a>   if op_def is None:
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2169'>2170</a>     op_def = self._graph._get_op_def(node_def.op)
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2170'>2171</a>   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2171'>2172</a>                             control_input_ops, op_def)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2172'>2173</a>   name = compat.as_str(node_def.name)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2174'>2175</a> self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\.venv\lib\site-packages\tensorflow\python\framework\ops.py:2010, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2005'>2006</a>   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2006'>2007</a>                                          serialized)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2008'>2009</a> try:
# -> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2009'>2010</a>   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2010'>2011</a> except errors.InvalidArgumentError as e:
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2011'>2012</a>   # Convert to ValueError for backwards compatibility.
#    <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/.venv/lib/site-packages/tensorflow/python/framework/ops.py?line=2012'>2013</a>   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
import utilities

import importlib
importlib.reload(utilities)


#creating graph with tas values from previous days AND predicted values for future n days
xDay = []
for i in range(1, n_ahead+1):
    xDay.append(42002+i)
plt.figure(figsize=(12, 8))
plt.plot(fc["day"], fc['tas'], label='previous days')
plt.plot(xDay, yhat_future, label='future days')
# plt.xticks(np.arange(0, len(xDay), step=100))
plt.xlabel("day")
plt.ylabel("tas")
plt.title("Predicted tas for future n days compared to values from previous days")
plt.legend()
plt.show()

# %%
import utilities
import importlib
importlib.reload(utilities)
from utilities import *

fig, ax = plot_temps()
ax.plot(xDay, yhat_future, 'g-')
fig.canvas.draw()
fig.canvas.flush_events()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\lstm_model.ipynb Cell 8' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model.ipynb#ch0000003?line=2'>3</a> importlib.reload(utilities)
#       <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model.ipynb#ch0000003?line=3'>4</a> from utilities import *
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model.ipynb#ch0000003?line=5'>6</a> fig, ax = plot_temps()
#       <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model.ipynb#ch0000003?line=6'>7</a> ax.plot(xDay, yhat_future, 'g-')
#       <a href='vscode-notebook-cell:/c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/lstm_model.ipynb#ch0000003?line=7'>8</a> fig.canvas.draw()
#
# File c:\Users\mathe\Documents\Code\KU\Spring_22\EECS_738\Project\utilities.py:51, in plot_temps()
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/utilities.py?line=48'>49</a> yticks = np.arange(0, len(y), step=0.3)
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/utilities.py?line=49'>50</a> plt.xticks(x[xticks], xyears[xticks])
# ---> <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/utilities.py?line=50'>51</a> plt.yticks(y[yticks], ytemps[yticks])
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/utilities.py?line=52'>53</a> z = np.polyfit(x, y, 1)
#      <a href='file:///c%3A/Users/mathe/Documents/Code/KU/Spring_22/EECS_738/Project/utilities.py?line=53'>54</a> p = np.poly1d(z)
#
# IndexError: arrays used as indices must be of integer (or boolean) type
